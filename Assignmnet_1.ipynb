# %%
#IDS 576 Assignment 1 - Question2
import numpy as np
import matplotlib.pyplot as plt

#question 2.1
def mse(prediction,groundTruth):
    prediction = np.array(prediction)
    groundTruth = np.array(groundTruth)
    squared_error = (prediction - groundTruth)**2
    print squared_error
    Mean = np.mean(squared_error)
    return Mean
np.random.seed(0)
h = 10 * random.random()
np.random.seed(0)
j = 20 * random.random()
print mse(h,j)
# Out:
# 42.234555101118296
# 42.234555101118296

# %%
#question 2.2
import random
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
#Plot the data
x = np.arange(0.01,1,0.01)  
def line(x, m=1, c=0):
    y = m*x + c
    return y
#fig = plt.figure()
plt.plot(x,line(x))

# %%
#Question 2.3
N = 100
X = np.empty(0)
for i in range(N):
    X = np.append(X,random.uniform(0.0,1.0))
Y = np.empty(0)
for i in range(N):
    Y = np.append(Y,m*X[i]+c)

# %%
#Question 2.4
# initialize parameters randomly
random.seed(0)
w = 10 * random.random()
random.seed(0)
b = 10 * random.random()
le = 0.001 #step size
tot_loss1 = np.empty(0)

for i in xrange(200):
    loss = 0.0
    for j in range(len(X)):
        Y_predict = w*X[j] + b
        loss = loss + ((Y_predict - Y[j])**2)/N #calculating mean squared error
    dw = np.sum(X*2*((np.dot(w,X)+b)-Y))/N
    db = np.sum(2*((np.dot(w,X)+b)-Y)/N)
    w = w - le*dw
    b = b - le*db
    tot_loss1 = np.append(tot_loss1,loss)
    if i % 10 == 0:
        print "iteration %d: MSE loss %f" % (i, loss)
# Out:
# iteration 0: MSE loss 120.149813
# iteration 10: MSE loss 113.811972
# iteration 20: MSE loss 107.809630
# iteration 30: MSE loss 102.125022
# iteration 40: MSE loss 96.741329
# iteration 50: MSE loss 91.642618
# iteration 60: MSE loss 86.813802
# iteration 70: MSE loss 82.240591
# iteration 80: MSE loss 77.909453
# iteration 90: MSE loss 73.807573
# iteration 100: MSE loss 69.922812
# iteration 110: MSE loss 66.243675
# iteration 120: MSE loss 62.759277
# iteration 130: MSE loss 59.459307
# iteration 140: MSE loss 56.334002
# iteration 150: MSE loss 53.374113
# iteration 160: MSE loss 50.570883
# iteration 170: MSE loss 47.916019
# iteration 180: MSE loss 45.401666
# iteration 190: MSE loss 43.020384

# %%
#Question 2.5
random.seed(0)
w = 10 * random.random()
random.seed(0)
b = 10 * random.random()
le = 0.01 # step size
tot_loss2 = np.empty(0)

for i in xrange(200):
    loss = 0.0
    for j in range(len(X)):
        Y_predict = w*X[j] + b
        loss = loss + ((Y_predict - Y[j])**2)/N #calculating mean squared error
    dw = np.sum(X*2*((np.dot(w,X)+b)-Y))/N
    db = np.sum(2*((np.dot(w,X)+b)-Y)/N)
    w = w - le*dw
    b = b - le*db
    tot_loss2 = np.append(tot_loss2,loss)
    if i % 10 == 0:
        print "iteration %d: MSE loss %f" % (i, loss)

plt.plot(tot_loss1,'r')
plt.plot(tot_loss2,'g')
plt.xlabel('Iterations')
plt.ylabel('cum_loss')
plt.show()
# Out:
# iteration 0: MSE loss 120.149813
# iteration 10: MSE loss 69.453736
# iteration 20: MSE loss 40.222419
# iteration 30: MSE loss 23.366136
# iteration 40: MSE loss 13.644438
# iteration 50: MSE loss 8.036075
# iteration 60: MSE loss 4.799225
# iteration 70: MSE loss 2.929680
# iteration 80: MSE loss 1.848492
# iteration 90: MSE loss 1.221878
# iteration 100: MSE loss 0.857405
# iteration 110: MSE loss 0.644130
# iteration 120: MSE loss 0.518088
# iteration 130: MSE loss 0.442401
# iteration 140: MSE loss 0.395808
# iteration 150: MSE loss 0.366049
# iteration 160: MSE loss 0.346055
# iteration 170: MSE loss 0.331749
# iteration 180: MSE loss 0.320779
# iteration 190: MSE loss 0.311789

# %%
#Question 6
m1 = 0.5
m2 = 1
c = 1
x1 = np.arange(0.0,1.0,0.001)
y1 = m1*x1+m2*(x1**2)+c
plt.plot(x1,y1)
plt.show()

N = 100
X1 = np.empty(0)
for i in range(N):
    X1 = np.append(X1,random.uniform(0.0,1.0))
Y1 = np.empty(0)
for i in range(N):
    Y1 = np.append(Y1,m1*X1[i]+m2*(X1[i]**2)+c)

random.seed(0)
w1 = 10 * random.random()
random.seed(0)
w2 = 10 * random.random()
random.seed(0)
b = 10 * random.random()
le = 0.001
tot_loss3 = np.empty(0)

for i in xrange(200):
    loss = 0.0
    for j in range(len(X1)):
        Y1_predict = w1*X1[j] + w2*(X1[j]**2) + b
        loss = loss + (Y1_predict - Y1[j])**2
    dw1 = np.sum(X1*2*((np.dot(w1,X1) + np.dot(w2,X1**2) + b)-Y1))/N
    dw2 = np.sum((X1**2)*2*((np.dot(w1,X1) + np.dot(w2,X1**2) + b)-Y1))/N
    db = np.sum(2*((np.dot(w1,X1) + np.dot(w2,X1**2) + b)-Y1))/N
    w1 = w1 - le*dw1
    w2 = w2 - le*dw2
    b = b - le*db
    tot_loss3 = np.append(tot_loss3,loss)
    if i % 10 == 0:
        print "iteration %d: loss %f" % (i, loss)

random.seed(0)
w1 = 10 * random.random()
random.seed(0)
w2 = 10 * random.random()
random.seed(0)
b = 10 * random.random()
le = 0.01
tot_loss4 = np.empty(0)

for i in xrange(200):
    loss = 0.0
    for j in range(len(X1)):
        Y1_predict = w1*X1[j] + w2*(X1[j]**2) + b
        loss = loss + (Y1_predict - Y1[j])**2
    dw1 = np.sum(X1*2*((np.dot(w1,X1) + np.dot(w2,X1**2) + b)-Y1))/N
    dw2 = np.sum((X1**2)*2*((np.dot(w1,X1) + np.dot(w2,X1**2) + b)-Y1))/N
    db = np.sum(2*((np.dot(w1,X1) + np.dot(w2,X1**2) + b)-Y1))/N
    w1 = w1 - le*dw1
    w2 = w2 - le*dw2
    b = b - le*db
    tot_loss4 = np.append(cum_loss4,loss)
    if i % 10 == 0:
        print "iteration %d: loss %f" % (i, loss)

plt.plot(tot_loss3,'r')
plt.plot(tot_loss4,'g')
plt.xlabel('Iterations')
plt.ylabel('tot_loss')
plt.show()

plt.plot(X,Y,'r')
plt.plot(x1,y1,'b')
plt.show()
# Out:
# iteration 0: loss 22452.518824
# iteration 10: loss 21196.801692
# iteration 20: loss 20012.031398
# iteration 30: loss 18894.195763
# iteration 40: loss 17839.509521
# iteration 50: loss 16844.401493
# iteration 60: loss 15905.502469
# iteration 70: loss 15019.633793
# iteration 80: loss 14183.796583
# iteration 90: loss 13395.161564
# iteration 100: loss 12651.059473
# iteration 110: loss 11948.972014
# iteration 120: loss 11286.523315
# iteration 130: loss 10661.471875
# iteration 140: loss 10071.702966
# iteration 150: loss 9515.221460
# iteration 160: loss 8990.145066
# iteration 170: loss 8494.697948
# iteration 180: loss 8027.204706
# iteration 190: loss 7586.084694
# iteration 0: loss 22452.518824
# iteration 10: loss 12555.147301
# iteration 20: loss 7063.082410
# iteration 30: loss 4013.360337
# iteration 40: loss 2317.805506
# iteration 50: loss 1373.178586
# iteration 60: loss 845.063483
# iteration 70: loss 548.065885
# iteration 80: loss 379.401743
# ...

# %%
#Question 2.7
m = 1
c = 2
x2 = np.arange(0.0,2.0,0.001)
y2 = np.tanh(m*x2+c)
plt.plot(x2,y2)
plt.show()

N = 100
X2 = np.empty(0)
for i in range(N):
    X2 = np.append(X2,random.uniform(0.0,2.0))
Y2 = np.empty(0)
for i in range(N):
    Y2 = np.append(Y2,np.tanh(m*X2[i]+c))

random.seed(0)
w = 10 * random.random()
random.seed(0)
b = 10 * random.random()
le = 0.001
tot_loss5 = np.empty(0)

for i in xrange(50):
    loss = 0.0
    for j in range(len(X2)):
        Y2_predict = np.tanh(w*X2[j]+b)
        loss = loss + ((Y2_predict - Y2[j])**2)/N
    dw = np.sum(X2*2*(np.tanh(np.dot(w,X2)+b)-Y2)*(1-(np.tanh(np.dot(w,X2)+b))**2))
    db = np.sum(2*(np.tanh(np.dot(w,X2)+b)-Y2)*(1-(np.tanh(np.dot(w,X2)+b))**2))
    w = w - le*dw
    b = b - le*db
    tot_loss5 = np.append(tot_loss5,loss)
    if i % 10 == 0:
        print "iteration %d: MSE loss %f" % (i, loss)

random.seed(0)
w = 10 * random.random()
random.seed(0)
b = 10 * random.random()
le = 0.01
tot_loss6 = np.empty(0)

for i in xrange(50):
    loss = 0.0
    for j in range(len(X2)):
        Y2_predict = np.tanh(w*X2[j]+b)
        loss = loss + ((Y2_predict - Y2[j])**2)/N
    dw = np.sum(X2*2*(np.tanh(np.dot(w,X2)+b)-Y2)*(1-(np.tanh(np.dot(w,X2)+b))**2))
    db = np.sum(2*(np.tanh(np.dot(w,X2)+b)-Y2)*(1-(np.tanh(np.dot(w,X2)+b))**2))
    w = w - le*dw
    b = b - le*db
    tot_loss6 = np.append(tot_loss6,loss)
    if i % 10 == 0:
        print "iteration %d: MSE loss %f" % (i, loss)

plt.plot(tot_loss5,'r')
plt.plot(tot_loss6,'g')
plt.xlabel('Iterations')
plt.ylabel('cum_loss')
plt.show()

plt.plot(x,y,'r')
plt.plot(x2,y2,'b')
plt.show()
# Out:
# iteration 0: loss 0.009176
# iteration 10: loss 0.009176
# iteration 20: loss 0.009176
# iteration 30: loss 0.009176
# iteration 40: loss 0.009176
# iteration 0: loss 0.009176
# iteration 10: loss 0.009176
# iteration 20: loss 0.009176
# iteration 30: loss 0.009176
# iteration 40: loss 0.009176

# %%
#IDS 576 Assignment1 -Question3
#3.1
def Logit():
        scores = np.dot(X, W) + B
        score_ex = np.exp(scores)
        batch_size = X.shape(0)
        probs = score_ex / np.sum(score_ex, axis = 1, keepdims = True)

        # Compute Logistic Loss Function
        corect_logprobs = -np.log(probs[range(batch_size),y])
        loss = np.sum(corect_logprobs) / batch_size
        return loss

# %%
#3.2
def regularization():
        scores = np.dot(X, W) + B
        exp_scores = np.exp(scores)
        probs = exp_scores / np.sum(exp_scores, axis = 1, keepdims = True)
        corect_logprobs = -np.log(probs[range(batch_size),y])
        data_loss = np.sum(corect_logprobs) / batch_size

        # L1 Regularization
        absolute_value = abs(Weights)
        l1_reg_loss = 0.5*reg*np.sum(absolute_value)
        l1_loss = data_loss + l1_reg_loss
       
        # L2 Regularization
        l2_reg_loss = 0.5*reg*np.sum(Weights*Weights)
        l2_loss = data_loss + l2_reg_loss
        
        # total loss
        loss = (l1_loss) + (l2_loss)
        return loss

# %%
#IDS 576 Assignment1 - Question 4
import random
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

#question 4.1
N = 100 # number of points per class
D = 2 # dimensionality
K = 3 # number of classes
X = np.zeros((N*K,D))
y = np.zeros(N*K, dtype='uint8')
for j in xrange(K):
    ix = range(N*j,N*(j+1))
    r = np.linspace(0.0,1,N) # radius
    t = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.2 # theta
    X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
    y[ix] = j

# %%
#question 4.2
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
#question 4.3
# initialize parameters randomly
np.random.seed(0)
W = 0.01 * np.random.randn(D,K)
b = np.zeros((1,K))
reg = 1e-3 
step_size = 1e-0
num_examples = X_train.shape[0]

train_accuracy_rate = np.empty(0)
test_accuracy_rate = np.empty(0)

for i in xrange(200):
    scores = np.dot(X_train, W) + b
    exp_scores = np.exp(scores)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
    corect_logprobs = -np.log(probs[range(num_examples),y_train])
    data_loss = np.sum(corect_logprobs)/num_examples
    reg_loss = 0.5*reg*np.sum(W*W)
    loss = data_loss + reg_loss
    if i % 10 == 0:
        print "iteration %d: loss %f" % (i, loss)

    dscores = probs
    dscores[range(num_examples),y_train] -= 1
    dscores /= num_examples

    dW = np.dot(X_train.T, dscores)
    db = np.sum(dscores, axis=0, keepdims=True)
    dW += reg*W

    W += -step_size * dW
    b += -step_size * db

    scores = np.dot(X_train,W) + b
    predicted_class = np.argmax(scores, axis = 1)
    train_accuracy_rate = np.append(train_accuracy_rate,np.mean(predicted_class == y_train))

    scores_test = np.dot(X_test,W) + b
    predicted_class_test = np.argmax(scores_test, axis = 1)
    test_accuracy_rate = np.append(test_accuracy_rate,np.mean(predicted_class_test == y_test))

print 'train data accuracy rate: %.4f' % (np.mean(predicted_class == y_train))
print 'test data accuracy rate: %.4f' % (np.mean(predicted_class_test == y_test))
plt.plot(range(200),train_accuracy_rate,'r')
plt.plot(range(200),test_accuracy_rate,'g')
plt.xlabel('iterations')
plt.ylabel('acc_rate')
plt.show()
# Out:
# iteration 0: loss 1.098633
# iteration 10: loss 0.921079
# iteration 20: loss 0.853241
# iteration 30: loss 0.821892
# iteration 40: loss 0.805420
# iteration 50: loss 0.795991
# iteration 60: loss 0.790263
# iteration 70: loss 0.786632
# iteration 80: loss 0.784254
# iteration 90: loss 0.782659
# iteration 100: loss 0.781567
# iteration 110: loss 0.780810
# iteration 120: loss 0.780277
# iteration 130: loss 0.779898
# iteration 140: loss 0.779627
# iteration 150: loss 0.779432
# iteration 160: loss 0.779290
# iteration 170: loss 0.779187
# iteration 180: loss 0.779111
# iteration 190: loss 0.779056
# train data accuracy rate: 0.5083
# test data accuracy rate: 0.5000

# %%
#question 4.4
np.random.seed(0)
W = 0.01 * np.random.randn(D,K)
b = np.zeros((1,K))
reg = 1e-0 

train_accuracy_rate = np.empty(0)
validation_accuracy_rate = np.empty(0)

kf = KFold(n_splits=5,shuffle=True,random_state=0)

for j in xrange(10):
    train_accuracy_sum = 0
    validation_accuracy_sum = 0
    for train, test in kf.split(X):
        np.random.seed(0)
        W = 0.01 * np.random.randn(D,K)
        b = np.zeros((1,K))
        X_train, X_test = X[train], X[test]
        y_train, y_test = y[train], y[test]
        num_examples = X_train.shape[0]
        for i in xrange(200):
            scores = np.dot(X_train, W) + b
            exp_scores = np.exp(scores)
            probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
            corect_logprobs = -np.log(probs[range(num_examples),y_train])
            data_loss = np.sum(corect_logprobs)/num_examples
            reg_loss = 0.5*reg*np.sum(W*W)
            loss = data_loss + reg_loss
            '''if i % 100 == 0:
                print "iteration %d: loss %f" % (i, loss)'''

            dscores = probs
            dscores[range(num_examples),y_train] -= 1
            dscores /= num_examples

            dW = np.dot(X_train.T, dscores)
            db = np.sum(dscores, axis=0, keepdims=True)
            dW += reg*W

            W += -step_size * dW
            b += -step_size * db

        scores = np.dot(X_train,W) + b
        predicted_class = np.argmax(scores, axis = 1)
        train_accuracy_sum = train_accuracy_sum + np.mean(predicted_class == y_train)

        scores_test = np.dot(X_test,W) + b
        predicted_class_test = np.argmax(scores_test, axis = 1)
        validation_accuracy_sum = validation_accuracy_sum + np.mean(predicted_class_test == y_test)

    avg_train_accuracy = train_accuracy_sum / 5
    train_accuracy_rate = np.append(train_accuracy_rate,avg_train_accuracy)

    avg_validation_accuracy = validation_accuracy_sum / 5
    validation_accuracy_rate = np.append(validation_accuracy_rate,avg_validation_accuracy)

    reg = reg/10.0

print 'train accuracy rate: %.4f' % (avg_train_accuracy)
print 'validation accuracy rate: %.4f' % (avg_validation_accuracy)
plt.plot(range(10),train_accuracy_rate,'r')
plt.plot(range(10),validation_accuracy_rate,'g')
plt.xlabel('Cross_validation 8 iteration')
plt.ylabel('acc_rate')
plt.show()
# Out:
# train accuracy rate: 0.5000
# validation accuracy rate: 0.5100

# %%
#question 4.5
reg = 1e-3
num_examples = X_train.shape[0]

train_accuracy_rate = np.empty(0)
validation_accuracy_rate = np.empty(0)

step_size = 500
for j in xrange(10):
    np.random.seed(0)
    W = 0.01 * np.random.randn(D,K)
    b = np.zeros((1,K))
    for i in xrange(200):
        scores = np.dot(X_train, W) + b
        exp_scores = np.exp(scores)
        probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
        corect_logprobs = -np.log(probs[range(num_examples),y_train])
        data_loss = np.sum(corect_logprobs)/num_examples
        reg_loss = 0.5*reg*np.sum(W*W)
        loss = data_loss + reg_loss
        if i % 100 == 0:
            print "iteration %d: loss %f" % (i, loss)

        dscores = probs
        dscores[range(num_examples),y_train] -= 1
        dscores /= num_examples

        dW = np.dot(X_train.T, dscores)
        db = np.sum(dscores, axis=0, keepdims=True)
        dW += reg*W

        W += -step_size * dW
        b += -step_size * db

    scores = np.dot(X_train,W) + b
    predicted_class = np.argmax(scores, axis = 1)
    train_accuracy_rate = np.append(train_accuracy_rate,np.mean(predicted_class == y_train))

    scores_test = np.dot(X_test,W) + b
    predicted_class_test = np.argmax(scores_test, axis = 1)
    validation_accuracy_rate = np.append(validation_accuracy_rate,np.mean(predicted_class_test == y_test))

    step_size = step_size/10.0

print 'train accuracy rate: %.2f' % (np.mean(predicted_class == y_train))
print 'validation accuracy rate: %.2f' % (np.mean(predicted_class_test == y_test))
plt.plot(range(10),train_accuracy_rate,'r')
plt.plot(range(10),validation_accuracy_rate,'g')
plt.xlabel('iterations')
plt.ylabel('acc_rate')
plt.show()

train_accuracy_rate = np.empty(0)
validation_accuracy_rate = np.empty(0)
iteration = 10

step_size = 1e-0
for j in xrange(10):
    np.random.seed(0)
    W = 0.01 * np.random.randn(D,K)
    b = np.zeros((1,K))
    for i in xrange(iteration):
        scores = np.dot(X_train, W) + b
        exp_scores = np.exp(scores)
        probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
        corect_logprobs = -np.log(probs[range(num_examples),y_train])
        data_loss = np.sum(corect_logprobs)/num_examples
        reg_loss = 0.5*reg*np.sum(W*W)
        loss = data_loss + reg_loss
        if i % 100 == 0:
            print "iteration %d: loss %f" % (i, loss)

        dscores = probs
        dscores[range(num_examples),y_train] -= 1
        dscores /= num_examples

        dW = np.dot(X_train.T, dscores)
        db = np.sum(dscores, axis=0, keepdims=True)
        dW += reg*W

        W += -step_size * dW
        b += -step_size * db

    scores = np.dot(X_train,W) + b
    predicted_class = np.argmax(scores, axis = 1)
    train_accuracy_rate = np.append(train_accuracy_rate,np.mean(predicted_class == y_train))

    scores_test = np.dot(X_test,W) + b
    predicted_class_test = np.argmax(scores_test, axis = 1)
    validation_accuracy_rate = np.append(validation_accuracy_rate,np.mean(predicted_class_test == y_test))

    iteration = iteration + 20

print 'train accuracy rate: %.2f' % (np.mean(predicted_class == y_train))
print 'validation accuracy rate: %.2f' % (np.mean(predicted_class_test == y_test))
plt.plot(range(10),train_accuracy_rate,'r')
plt.plot(range(10),validation_accuracy_rate,'g')
plt.xlabel('iterations')
plt.ylabel('acc_rate')
plt.show()
# Out:
# iteration 0: loss 1.098633
# iteration 100: loss 134.642345
# iteration 0: loss 1.098633
# iteration 100: loss 6.041620
# iteration 0: loss 1.098633
# iteration 100: loss 0.778898
# iteration 0: loss 1.098633
# iteration 100: loss 0.796328
# iteration 0: loss 1.098633
# iteration 100: loss 0.988999
# iteration 0: loss 1.098633
# iteration 100: loss 1.084741
# iteration 0: loss 1.098633
# iteration 100: loss 1.097207
# iteration 0: loss 1.098633
# iteration 100: loss 1.098490
# iteration 0: loss 1.098633
# iteration 100: loss 1.098619
# iteration 0: loss 1.098633
# iteration 100: loss 1.098632
# train accuracy rate: 0.52
# validation accuracy rate: 0.52
# iteration 0: loss 1.098633
# iteration 0: loss 1.098633
# iteration 0: loss 1.098633
# iteration 0: loss 1.098633
# iteration 0: loss 1.098633
# iteration 0: loss 1.098633
# iteration 100: loss 0.781567
# iteration 0: loss 1.098633
# iteration 100: loss 0.781567
# iteration 0: loss 1.098633
# iteration 100: loss 0.781567
# ...

# %%
#question 4.6
reg = 1e-0 
num_examples = X_train.shape[0]

train_accuracy_rate = np.empty(0)
validation_accuracy_rate = np.empty(0)

step_size = 1e-0
for j in xrange(100):
    np.random.seed(0)
    W = 0.01 * np.random.randn(D,K)
    b = np.zeros((1,K))
    for i in xrange(200):
        scores = np.dot(X_train, W) + b
        exp_scores = np.exp(scores)
        probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
        corect_logprobs = -np.log(probs[range(num_examples),y_train])
        data_loss = np.sum(corect_logprobs)/num_examples
        reg_loss = 0.5*reg*np.sum(W*W)
        loss = data_loss + reg_loss
        '''if i % 100 == 0:
            print "iteration %d: loss %f" % (i, loss)'''

        dscores = probs
        dscores[range(num_examples),y_train] -= 1
        dscores /= num_examples

        dW = np.dot(X_train.T, dscores)
        db = np.sum(dscores, axis=0, keepdims=True)
        dW += reg*W

        W += -step_size * dW
        b += -step_size * db

    scores = np.dot(X_train,W) + b
    predicted_class = np.argmax(scores, axis = 1)
    train_accuracy_rate = np.append(train_accuracy_rate,np.mean(predicted_class == y_train))

    scores_test = np.dot(X_test,W) + b
    predicted_class_test = np.argmax(scores_test, axis = 1)
    validation_accuracy_rate = np.append(validation_accuracy_rate,np.mean(predicted_class_test == y_test))

    reg = reg/10.0

print 'train accuracy rate: %.2f' % (np.mean(predicted_class == y_train))
print 'validation accuracy rate: %.2f' % (np.mean(predicted_class_test == y_test))
plt.plot(range(100),train_accuracy_rate,'r')
plt.plot(range(100),validation_accuracy_rate,'g')
plt.xlabel('iterations')
plt.ylabel('acc_rate')
plt.show()

train_accuracy_rate = np.empty(0)
validation_accuracy_rate = np.empty(0)
reg = 0

np.random.seed(0)
W = 0.01 * np.random.randn(D,K)
b = np.zeros((1,K))

for i in xrange(200):
    scores = np.dot(X_train, W) + b
    exp_scores = np.exp(scores)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
    corect_logprobs = -np.log(probs[range(num_examples),y_train])
    data_loss = np.sum(corect_logprobs)/num_examples
    reg_loss = 0.5*reg*np.sum(W*W)
    loss = data_loss + reg_loss
    '''if i % 100 == 0:
        print "iteration %d: loss %f" % (i, loss)'''

    dscores = probs
    dscores[range(num_examples),y_train] -= 1
    dscores /= num_examples

    dW = np.dot(X_train.T, dscores)
    db = np.sum(dscores, axis=0, keepdims=True)
    dW += reg*W

    W += -step_size * dW
    b += -step_size * db

scores = np.dot(X_train,W) + b
predicted_class = np.argmax(scores, axis = 1)
print 'train accuracy: %.2f' % (np.mean(predicted_class == y_train))

scores_test = np.dot(X_test,W) + b
predicted_class_test = np.argmax(scores_test, axis = 1)
print 'validation accuracy: %.2f' % (np.mean(predicted_class_test == y_test))

print 'train accuracy rate: %.2f' % (np.mean(predicted_class == y_train))
print 'validation accuracy rate: %.2f' % (np.mean(predicted_class_test == y_test))
plt.plot(range(100),train_accuracy_rate,'r')
plt.plot(range(100),validation_accuracy_rate,'g')
plt.xlabel('iterations')
plt.ylabel('acc_rate')
plt.show()
# Out:
# train accuracy rate: 0.51
# validation accuracy rate: 0.48
# train accuracy: 0.51
# validation accuracy: 0.48
# train accuracy rate: 0.51
# validation accuracy rate: 0.48
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-cf686ffa2a8a> in <module>()
#      91 print 'train accuracy rate: %.2f' % (np.mean(predicted_class == y_train))
#      92 print 'validation accuracy rate: %.2f' % (np.mean(predicted_class_test == y_test))
# ---> 93 plt.plot(range(100),train_accuracy_rate,'r')
#      94 plt.plot(range(100),validation_accuracy_rate,'g')
#      95 plt.xlabel('iterations')
#
# /Applications/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3238                       mplDeprecation)
#    3239     try:
# -> 3240         ret = ax.plot(*args, **kwargs)
#    3241     finally:
#    3242         ax._hold = washold
#
# ...

# %%
#question 4.7
reg = 1e-3
step_size = 1e-0

train_accuracy_rate = np.empty(0)
validation_accuracy_rate = np.empty(0)

percentage = 0.1

for j in xrange(8):
    np.random.seed(0)
    W = 0.01 * np.random.randn(D,K)
    b = np.zeros((1,K))
    X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y, test_size=percentage, random_state=1)
    num_examples = X_train1.shape[0]
    for i in xrange(200):
        scores = np.dot(X_train1, W) + b
        exp_scores = np.exp(scores)
        probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
        corect_logprobs = -np.log(probs[range(num_examples),y_train1])
        data_loss = np.sum(corect_logprobs)/num_examples
        reg_loss = 0.5*reg*np.sum(W*W)
        loss = data_loss + reg_loss
        if i % 100 == 0:
            print "iteration %d: loss %f" % (i, loss)

        dscores = probs
        dscores[range(num_examples),y_train1] -= 1
        dscores /= num_examples

        dW = np.dot(X_train1.T, dscores)
        db = np.sum(dscores, axis=0, keepdims=True)
        dW += reg*W

        W += -step_size * dW
        b += -step_size * db

    scores = np.dot(X_train1,W) + b
    predicted_class = np.argmax(scores, axis = 1)
    train_accuracy_rate = np.append(train_accuracy_rate,np.mean(predicted_class == y_train1))

    scores_test = np.dot(X_test1,W) + b
    predicted_class_test = np.argmax(scores_test, axis = 1)
    validation_accuracy_rate = np.append(validation_accuracy_rate,np.mean(predicted_class_test == y_test1))

    percentage = percentage + 0.1

print 'train accuracy rate: %.2f' % (np.mean(predicted_class == y_train1))
print 'validation accuracy rate: %.2f' % (np.mean(predicted_class_test == y_test1))
plt.plot(range(8),train_accuracy_rate,'r')
plt.plot(range(8),validation_accuracy_rate,'g')
plt.xlabel('Split Percentage')
plt.ylabel('acc_rate')
plt.show()
# Out:
# iteration 0: loss 1.098408
# iteration 100: loss 0.781191
# iteration 0: loss 1.098308
# iteration 100: loss 0.788783
# iteration 0: loss 1.098327
# iteration 100: loss 0.790775
# iteration 0: loss 1.098346
# iteration 100: loss 0.785405
# iteration 0: loss 1.098669
# iteration 100: loss 0.757991
# iteration 0: loss 1.098434
# iteration 100: loss 0.793602
# iteration 0: loss 1.098142
# iteration 100: loss 0.748512
# iteration 0: loss 1.097903
# iteration 100: loss 0.776939
# train accuracy rate: 0.50
# validation accuracy rate: 0.48

# %%
#IDS 576 Assignment 1 - Question 5
# Question 5.1
# %matplotlib inline
import random
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

N = 100 # number of points per class
D = 2 # dimensionality
K = 3 # number of classes
h = 30 # number of hidden layer neuron
X = np.zeros((N*K,D))
y = np.zeros(N*K, dtype='uint8')
for j in range(K):
    ix = range(N*j,N*(j+1))
    r = np.linspace(0.0,1,N) # radius
    t = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.2 # theta
    X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
    y[ix] = j


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)


# initialize parameters randomly
np.random.seed(0)
W = 0.01 * np.random.randn(D,h)
b = np.zeros((1,h))
W2 = 0.01 * np.random.randn(h,K)
b2 = np.zeros((1,K))
reg = 1e-3 
step_size = 1e-0
num_examples = X_train.shape[0]

accuracy_training = np.empty(0)
accuracy_testing = np.empty(0)

for i in range(10000):
  
    # evaluate class scores, [N x K]
    hidden_layer = np.maximum(0, np.dot(X_train, W) + b) # ReLU activation
    scores = np.dot(hidden_layer, W2) + b2
  
    # compute the class probabilities
    exp_scores = np.exp(scores)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True) # [N x K]
  
    # compute the loss: average cross-entropy loss and regularization
    corect_logprobs = -np.log(probs[range(num_examples),y_train])
    data_loss = np.sum(corect_logprobs)/num_examples
  
    reg_loss = 0.5*reg*np.sum(W*W) + 0.5*reg*np.sum(W2*W2)
    loss = data_loss + reg_loss
    if i % 1000 == 0:
        print ("iteration",i,": loss ",loss)
  
    # compute the gradient on scores
    dscores = probs
    dscores[range(num_examples),y_train] -= 1
    dscores /= num_examples
  
    # backpropate the gradient to the parameters
    # first backprop into parameters W2 and b2
    dW2 = np.dot(hidden_layer.T, dscores)
    db2 = np.sum(dscores, axis=0, keepdims=True)
    # next backprop into hidden layer
    dhidden = np.dot(dscores, W2.T)
    # backprop the ReLU non-linearity
    dhidden[hidden_layer <= 0] = 0
    # finally into W,b
    dW = np.dot(X_train.T, dhidden)
    db = np.sum(dhidden, axis=0, keepdims=True)
  
    # add regularization gradient contribution
    dW2 += reg * W2
    dW += reg * W
  
    # perform a parameter update
    W += -step_size * dW
    b += -step_size * db
    W2 += -step_size * dW2
    b2 += -step_size * db2

    hidden_layer = np.maximum(0, np.dot(X_train, W) + b)
    scores_train = np.dot(hidden_layer,W2) + b2
    predicted_class = np.argmax(scores_train, axis = 1)
    accuracy_training = np.append(accuracy_training,np.mean(predicted_class == y_train))

    hidden_layer = np.maximum(0, np.dot(X_test, W) + b)
    scores_test = np.dot(hidden_layer, W2) + b2
    predicted_class_test = np.argmax(scores_test, axis=1)
    accuracy_testing = np.append(accuracy_testing,np.mean(predicted_class_test == y_test))

print ('Accuracy on training set:',np.mean(predicted_class == y_train))
print ('Accuracy on validation set:',np.mean(predicted_class_test == y_test))
plt.plot(range(10000),accuracy_training)
plt.plot(range(10000),accuracy_testing)
plt.show()
# Out:
# ('iteration', 0, ': loss ', 1.098588422051515)
# ('iteration', 1000, ': loss ', 0.4475261232249348)
# ('iteration', 2000, ': loss ', 0.26799502213068055)
# ('iteration', 3000, ': loss ', 0.25256421962761705)
# ('iteration', 4000, ': loss ', 0.2632336471138519)
# ('iteration', 5000, ': loss ', 0.2535571660618733)
# ('iteration', 6000, ': loss ', 0.2506629539089199)
# ('iteration', 7000, ': loss ', 0.24942600077826338)
# ('iteration', 8000, ': loss ', 0.24865672422466106)
# ('iteration', 9000, ': loss ', 0.2483381530002477)
# ('Accuracy on training set:', 0.9833333333333333)
# ('Accuracy on validation set:', 0.9833333333333333)

# %%
# Question 5.2
import random
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

N = 100 # number of points per class
D = 2 # dimensionality
K = 3 # number of classes
h = 30 # size of hidden layer
X = np.zeros((N*K,D))
y = np.zeros(N*K, dtype='uint8')
for j in range(K):
    ix = range(N*j,N*(j+1))
    r = np.linspace(0.0,1,N) # radius
    t = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.2 # theta
    X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
    y[ix] = j


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)


# initialize parameters randomly
np.random.seed(0)
W = 0.01 * np.random.randn(D,h)
b = np.zeros((1,h))
W2 = 0.01 * np.random.randn(h,K)
b2 = np.zeros((1,K))
reg = 1e-3 
step_size = 1e-0
num_examples = X_train.shape[0]

accuracy_training = np.empty(0)
accuracy_testing = np.empty(0)

for i in range(10000):
  
    # evaluate class scores, [N x K]
    hidden_layer = np.maximum(0.1, np.dot(X_train, W) + b) # note, Leaked ReLU activation
    scores = np.dot(hidden_layer, W2) + b2
  
    # compute the class probabilities
    exp_scores = np.exp(scores)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True) # [N x K]
  
    # compute the loss: average cross-entropy loss and regularization
    corect_logprobs = -np.log(probs[range(num_examples),y_train])
    data_loss = np.sum(corect_logprobs)/num_examples
  
    reg_loss = 0.5*reg*np.sum(W*W) + 0.5*reg*np.sum(W2*W2)
    loss = data_loss + reg_loss
    if i % 1000 == 0:
        print ("iteration",i,": loss ",loss)
  
    # compute the gradient on scores
    dscores = probs
    dscores[range(num_examples),y_train] -= 1
    dscores /= num_examples
  
    # backpropate the gradient to the parameters
    # first backprop into parameters W2 and b2
    dW2 = np.dot(hidden_layer.T, dscores)
    db2 = np.sum(dscores, axis=0, keepdims=True)
    # next backprop into hidden layer
    dhidden = np.dot(dscores, W2.T)
    # backprop the ReLU non-linearity
    dhidden[hidden_layer <= 0] = 0
    # finally into W,b
    dW = np.dot(X_train.T, dhidden)
    db = np.sum(dhidden, axis=0, keepdims=True)
  
    # add regularization gradient contribution
    dW2 += reg * W2
    dW += reg * W
  
    # perform a parameter update
    W += -step_size * dW
    b += -step_size * db
    W2 += -step_size * dW2
    b2 += -step_size * db2

    hidden_layer = np.maximum(0.1, np.dot(X_train, W) + b)
    scores_train = np.dot(hidden_layer,W2) + b2
    predicted_class = np.argmax(scores_train, axis = 1)
    accuracy_training = np.append(accuracy_training,np.mean(predicted_class == y_train))

    hidden_layer = np.maximum(0.1, np.dot(X_test, W) + b)
    scores_test = np.dot(hidden_layer, W2) + b2
    predicted_class_test = np.argmax(scores_test, axis=1)
    accuracy_testing = np.append(accuracy_testing,np.mean(predicted_class_test == y_test))

print ('Accuracy on training set:',np.mean(predicted_class == y_train))
print ('Accuracy on validation set:',np.mean(predicted_class_test == y_test))
plt.plot(range(10000),accuracy_training)
plt.plot(range(10000),accuracy_testing)
plt.show()
# Out:
# ('iteration', 0, ': loss ', 1.0985893934641013)
# ('iteration', 1000, ': loss ', 0.7635259527763845)
# ('iteration', 2000, ': loss ', 0.7555446443879956)
# ('iteration', 3000, ': loss ', 0.678670162654273)
# ('iteration', 4000, ': loss ', 0.5633607813276412)
# ('iteration', 5000, ': loss ', 0.7348019023700946)
# ('iteration', 6000, ': loss ', 0.7178884080231236)
# ('iteration', 7000, ': loss ', 0.65455246810255)
# ('iteration', 8000, ': loss ', 0.809503725433508)
# ('iteration', 9000, ': loss ', 0.7499711097879185)
# ('Accuracy on training set:', 0.6)
# ('Accuracy on validation set:', 0.65)

# %%
# Question 5.3
import random
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

N = 100 # number of points per class
D = 2 # dimensionality
K = 3 # number of classes
h = 30 # number of hidden layers for hidden layer1
#h2 = 30 # number of hidden layers for hidden layer2

X = np.zeros((N*K,D))
y = np.zeros(N*K, dtype='uint8')
for j in range(K):
    ix = range(N*j,N*(j+1))
    r = np.linspace(0.0,1,N) # radius
    t = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.2 # theta
    X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
    y[ix] = j


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)


# initialize parameters randomly
np.random.seed(0)
W1 = 0.01 * np.random.randn(D,h)
b1 = np.zeros((1,h))
W2 = 0.01 * np.random.randn(D,h)
b2 = np.zeros((1,h))
W3 = 0.01 * np.random.randn(h,K)
b3 = np.zeros((1,K))
reg = 1e-3 
step_size = 1e-0
num_examples = X_train.shape[0]

accuracy_training = np.empty(0)
accuracy_testing = np.empty(0)

for i in range(10000):
  
    # evaluate class scores, [N x K]
    hidden_layer = np.maximum(np.dot(X_train, W2) + b2, np.dot(X_train, W1) + b1) # maxout non-linearity
    scores = np.dot(hidden_layer, W3) + b3
  
    # compute the class probabilities
    exp_scores = np.exp(scores)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True) # [N x K]
  
    # compute the loss: average cross-entropy loss and regularization
    corect_logprobs = -np.log(probs[range(num_examples),y_train])
    data_loss = np.sum(corect_logprobs)/num_examples
  
    reg_loss = 0.5*reg*np.sum(W1*W1) + 0.5*reg*np.sum(W2*W2) + 0.5*reg*np.sum(W3*W3)
    loss = data_loss + reg_loss
    if i % 1000 == 0:
        print ("iteration",i,": loss ",loss)
  
    # compute the gradient on scores
    dscores = probs
    dscores[range(num_examples),y_train] -= 1
    dscores /= num_examples
  
    # backpropate the gradient to the parameters
    # first backprop into parameters W2 and b2
    
    dW3 = np.dot(hidden_layer.T, dscores)
    db3 = np.sum(dscores, axis=0, keepdims=True)
    
    # next backprop into hidden layer
    dhidden = np.dot(dscores, W3.T)
    
    # backprop the ReLU non-linearity
    dhidden[hidden_layer <= 0] = 0
    
    # finally into W,b
    dW1 = np.dot(X_train.T, dhidden)
    db1 = np.sum(dhidden, axis=0, keepdims=True)
  
    # add regularization gradient contribution
    dW3 += reg * W3
    dW2 += reg * W3
    dW1 += reg * W1
  
    # perform a parameter update
    W1 += -step_size * dW1
    b1 += -step_size * db1
    W2 += -step_size * dW1
    b2 += -step_size * db1
    W3 += -step_size * dW3
    b3 += -step_size * db3

    hidden_layer = np.maximum(np.dot(X_train, W2) + b2, np.dot(X_train, W1) + b1)
    scores_train = np.dot(hidden_layer,W3) + b3
    
    predicted_class = np.argmax(scores_train, axis = 1)
    accuracy_training = np.append(accuracy_training,np.mean(predicted_class == y_train))

    hidden_layer = np.maximum(np.dot(X_test, W2) + b2, np.dot(X_test, W) + b)
    scores_test = np.dot(hidden_layer, W3) + b3
    predicted_class_test = np.argmax(scores_test, axis=1)
    accuracy_testing = np.append(accuracy_testing,np.mean(predicted_class_test == y_test))

print ('Accuracy on training set:',np.mean(predicted_class == y_train))
print ('Accuracy on validation set:',np.mean(predicted_class_test == y_test))
plt.plot(range(10000),accuracy_training)
plt.plot(range(10000),accuracy_testing)
plt.show()
# Out:
# ('iteration', 0, ': loss ', 1.0986006106465254)
# ('iteration', 1000, ': loss ', 0.7558428479937983)
# ('iteration', 2000, ': loss ', 0.7506427026925496)
# ('iteration', 3000, ': loss ', 0.7498847648124988)
# ('iteration', 4000, ': loss ', 0.7497981737173463)
# ('iteration', 5000, ': loss ', 0.7498371945147692)
# ('iteration', 6000, ': loss ', 0.749744187471204)
# ('iteration', 7000, ': loss ', 0.7497515337802448)
# ('iteration', 8000, ': loss ', 0.7496050457702755)
# ('iteration', 9000, ': loss ', 0.749607633485899)
# ('Accuracy on training set:', 0.5333333333333333)
# ('Accuracy on validation set:', 0.48333333333333334)

# %%
# Question 5.4

# %%
#IDS 576 - Assignment1 question 6
#part 6
#question 6.1  - & Iterations so very long code
import random
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
import cPickle, gzip, numpy

# Load the dataset
f = gzip.open('mnist.pkl.gz', 'rb')
train_set, valid_set, test_set = cPickle.load(f)
f.close()

train_set_x = train_set[0]
train_set_y = train_set[1]

valid_set_x = valid_set[0]
valid_set_y = valid_set[1]

test_set_x = test_set[0]
test_set_y = test_set[1]

X_train = train_set_x
y_train = train_set_y

D = 784 # dimensionality
K = 10 # number of classes
h = 100 # size of hidden layer

np.random.seed(0)
W = 0.01 * np.random.randn(D,h)
b = np.zeros((1,h))
np.random.seed(0)
W2 = 0.01 * np.random.randn(h,K)
b2 = np.zeros((1,K))

step_size = 1e-0
reg = 1e-3
num_examples = train_set_x.shape[0]

train_accuracy_rate = np.empty(0)
test_accuracy_rate = np.empty(0)

for i in xrange(100):
    hidden_layer = np.maximum(0, np.dot(train_set_x, W) + b)
    scores = np.dot(hidden_layer, W2) + b2
    exp_scores = np.exp(scores)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
  
    corect_logprobs = -np.log(probs[range(num_examples),train_set_y])
    data_loss = np.sum(corect_logprobs)/num_examples
    reg_loss = 0.5*reg*np.sum(W*W) + 0.5*reg*np.sum(W2*W2)
    loss = data_loss + reg_loss
    if i % 10 == 0:
        print "iteration %d: loss %f" % (i, loss)
  
    dscores = probs
    dscores[range(num_examples),train_set_y] -= 1
    dscores /= num_examples
  
    dW2 = np.dot(hidden_layer.T, dscores)
    db2 = np.sum(dscores, axis=0, keepdims=True)
    dhidden = np.dot(dscores, W2.T)
    dhidden[hidden_layer <= 0] = 0
    dW = np.dot(train_set_x.T, dhidden)
    db = np.sum(dhidden, axis=0, keepdims=True)
  
    dW2 += reg * W2
    dW += reg * W
  
    W += -step_size * dW
    b += -step_size * db
    W2 += -step_size * dW2
    b2 += -step_size * db2

    hidden_layer = np.maximum(0, np.dot(train_set_x, W) + b)
    scores = np.dot(hidden_layer, W2) + b2
    predicted_class = np.argmax(scores, axis=1)
    train_accuracy_rate = np.append(train_accuracy_rate,np.mean(predicted_class == train_set_y))
    
    hidden_layer_test = np.maximum(0, np.dot(test_set_x, W) + b)
    scores_test = np.dot(hidden_layer_test, W2) + b2
    predicted_class_test = np.argmax(scores_test, axis=1)
    test_accuracy_rate = np.append(test_accuracy_rate,np.mean(predicted_class_test == test_set_y))

print 'train data accuracy rate: %.2f' % (np.mean(predicted_class == train_set_y))
print 'test data accuracy rate: %.2f' % (np.mean(predicted_class_test == test_set_y))
plt.plot(range(100),train_accuracy_rate,label='Train Accuracy Rate')
plt.plot(range(100),test_accuracy_rate,label='Test Accuracy Rate')
plt.title('Loss of MNIST Dataset on Relu Model')
plt.xlabel('Number of Iterations')
plt.ylabel('Accuracy Rate')
plt.legend(loc='upper right')
plt.show()

train_accuracy_rate = np.empty(0)
validation_accuracy_rate = np.empty(0)
xticks = np.empty(0)

reg = 1e-0
kf = KFold(n_splits=5,shuffle=True,random_state=0)

for j in xrange(10):
    train_accuracy_sum = 0
    validation_accuracy_sum = 0
    for train, test in kf.split(train_set_x):
        np.random.seed(0)
        W = 0.01 * np.random.randn(D,h)
        b = np.zeros((1,h))
        np.random.seed(0)
        W2 = 0.01 * np.random.randn(h,K)
        b2 = np.zeros((1,K))
        train_set_x1, valid_set_x1 = train_set_x[train], train_set_x[test]
        train_set_y1, valid_set_y1 = train_set_y[train], train_set_y[test]
        num_examples = train_set_x1.shape[0]
        for i in xrange(100):
            hidden_layer = np.maximum(0, np.dot(train_set_x1, W) + b)
            scores = np.dot(hidden_layer, W2) + b2
            exp_scores = np.exp(scores)
            probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
  
            corect_logprobs = -np.log(probs[range(num_examples),train_set_y1])
            data_loss = np.sum(corect_logprobs)/num_examples
            reg_loss = 0.5*reg*np.sum(W*W) + 0.5*reg*np.sum(W2*W2)
            loss = data_loss + reg_loss
            if i % 50 == 0:
                print "iteration %d: loss %f" % (i, loss)
  
            dscores = probs
            dscores[range(num_examples),train_set_y1] -= 1
            dscores /= num_examples
  
            dW2 = np.dot(hidden_layer.T, dscores)
            db2 = np.sum(dscores, axis=0, keepdims=True)
            dhidden = np.dot(dscores, W2.T)
            dhidden[hidden_layer <= 0] = 0
            dW = np.dot(train_set_x1.T, dhidden)
            db = np.sum(dhidden, axis=0, keepdims=True)
  
            dW2 += reg * W2
            dW += reg * W
  
            W += -step_size * dW
            b += -step_size * db
            W2 += -step_size * dW2
            b2 += -step_size * db2

        hidden_layer = np.maximum(0, np.dot(train_set_x1, W) + b)
        scores = np.dot(hidden_layer, W2) + b2
        predicted_class = np.argmax(scores, axis=1)
        train_accuracy_sum = train_accuracy_sum + np.mean(predicted_class == train_set_y1)
    
        hidden_layer_test = np.maximum(0, np.dot(valid_set_x1, W) + b)
        scores_test = np.dot(hidden_layer_test, W2) + b2
        predicted_class_test = np.argmax(scores_test, axis=1)
        validation_accuracy_sum = validation_accuracy_sum + np.mean(predicted_class_test == valid_set_y1)

    avg_train_accuracy = train_accuracy_sum / 5
    train_accuracy_rate = np.append(train_accuracy_rate,avg_train_accuracy)

    avg_validation_accuracy = validation_accuracy_sum / 5
    validation_accuracy_rate = np.append(validation_accuracy_rate,avg_validation_accuracy)

    xticks = np.append(xticks,reg)
    
    reg = reg/10.0

print 'training accuracy rate: %.2f' % (avg_train_accuracy)
print 'test accuracy rate: %.2f' % (avg_validation_accuracy)
plt.xticks(range(10),xticks)
plt.plot(range(10),train_accuracy_rate,label='Train Accuracy Rate')
plt.plot(range(10),validation_accuracy_rate,label='Validation Accuracy Rate')
plt.title('Loss of MNIST Dataset Five Folds Cross Validation on Relu Model')
plt.xlabel('Regularization Values')
plt.ylabel('Accuracy Rate')
plt.legend(loc='upper right')
plt.show()

reg = 1e-3
train_accuracy_rate = np.empty(0)
validation_accuracy_rate = np.empty(0)
xticks = np.empty(0)

step_size = 5
for j in xrange(10):
    np.random.seed(0)
    W = 0.01 * np.random.randn(D,h)
    b = np.zeros((1,h))
    np.random.seed(0)
    W2 = 0.01 * np.random.randn(h,K)
    b2 = np.zeros((1,K))
    for i in xrange(100):
        hidden_layer = np.maximum(0, np.dot(train_set_x, W) + b)
        scores = np.dot(hidden_layer, W2) + b2
        exp_scores = np.exp(scores)
        probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
  
        corect_logprobs = -np.log(probs[range(num_examples),train_set_y])
        data_loss = np.sum(corect_logprobs)/num_examples
        reg_loss = 0.5*reg*np.sum(W*W) + 0.5*reg*np.sum(W2*W2)
        loss = data_loss + reg_loss
        if i % 50 == 0:
            print "iteration %d: loss %f" % (i, loss)
  
        dscores = probs
        dscores[range(num_examples),train_set_y] -= 1
        dscores /= num_examples
  
        dW2 = np.dot(hidden_layer.T, dscores)
        db2 = np.sum(dscores, axis=0, keepdims=True)
        dhidden = np.dot(dscores, W2.T)
        dhidden[hidden_layer <= 0] = 0
        dW = np.dot(train_set_x.T, dhidden)
        db = np.sum(dhidden, axis=0, keepdims=True)
  
        dW2 += reg * W2
        dW += reg * W
  
        W += -step_size * dW
        b += -step_size * db
        W2 += -step_size * dW2
        b2 += -step_size * db2

    hidden_layer = np.maximum(0, np.dot(train_set_x, W) + b)
    scores = np.dot(hidden_layer, W2) + b2
    predicted_class = np.argmax(scores, axis=1)
    train_accuracy_rate = np.append(train_accuracy_rate,np.mean(predicted_class == train_set_y))
    
    hidden_layer_test = np.maximum(0, np.dot(valid_set_x, W) + b)
    scores_test = np.dot(hidden_layer_test, W2) + b2
    predicted_class_test = np.argmax(scores_test, axis=1)
    validation_accuracy_rate = np.append(validation_accuracy_rate,np.mean(predicted_class_test == valid_set_y))

    xticks = np.append(xticks,step_size)

    step_size = step_size/10.0

print 'training accuracy rate: %.2f' % (np.mean(predicted_class == train_set_y))
print 'validation accuracy rate: %.2f' % (np.mean(predicted_class_test == valid_set_y))
plt.xticks(range(10),xticks)
plt.plot(range(10),train_accuracy_rate,label='Train Accuracy Rate')
plt.plot(range(10),validation_accuracy_rate,label='Validation Accuracy Rate')
plt.title('Loss of MNIST Dataset Different Learning Rates on Relu Model')
plt.xlabel('Learning Rates')
plt.ylabel('Accuracy Rate')
plt.legend(loc='upper right')
plt.show()

step_size = 1e-0
train_accuracy_rate = np.empty(0)
validation_accuracy_rate = np.empty(0)
xticks = np.empty(0)

iteration = 10
for j in xrange(10):
    np.random.seed(0)
    W = 0.01 * np.random.randn(D,h)
    b = np.zeros((1,h))
    np.random.seed(0)
    W2 = 0.01 * np.random.randn(h,K)
    b2 = np.zeros((1,K))
    for i in xrange(iteration):
        hidden_layer = np.maximum(0, np.dot(train_set_x, W) + b)
        scores = np.dot(hidden_layer, W2) + b2
        exp_scores = np.exp(scores)
        probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
  
        corect_logprobs = -np.log(probs[range(num_examples),train_set_y])
        data_loss = np.sum(corect_logprobs)/num_examples
        reg_loss = 0.5*reg*np.sum(W*W) + 0.5*reg*np.sum(W2*W2)
        loss = data_loss + reg_loss
        if i % 50 == 0:
            print "iteration %d: loss %f" % (i, loss)
  
        dscores = probs
        dscores[range(num_examples),train_set_y] -= 1
        dscores /= num_examples
  
        dW2 = np.dot(hidden_layer.T, dscores)
        db2 = np.sum(dscores, axis=0, keepdims=True)
        dhidden = np.dot(dscores, W2.T)
        dhidden[hidden_layer <= 0] = 0
        dW = np.dot(train_set_x.T, dhidden)
        db = np.sum(dhidden, axis=0, keepdims=True)
  
        dW2 += reg * W2
        dW += reg * W
  
        W += -step_size * dW
        b += -step_size * db
        W2 += -step_size * dW2
        b2 += -step_size * db2

    hidden_layer = np.maximum(0, np.dot(train_set_x, W) + b)
    scores = np.dot(hidden_layer, W2) + b2
    predicted_class = np.argmax(scores, axis=1)
    train_accuracy_rate = np.append(train_accuracy_rate,np.mean(predicted_class == train_set_y))
    
    hidden_layer_test = np.maximum(0, np.dot(valid_set_x, W) + b)
    scores_test = np.dot(hidden_layer_test, W2) + b2
    predicted_class_test = np.argmax(scores_test, axis=1)
    validation_accuracy_rate = np.append(validation_accuracy_rate,np.mean(predicted_class_test == valid_set_y))

    xticks = np.append(xticks,iteration)
    
    iteration = iteration + 20

print 'training accuracy rate: %.2f' % (np.mean(predicted_class == train_set_y))
print 'validation accuracy rate: %.2f' % (np.mean(predicted_class_test == valid_set_y))
plt.xticks(range(10),xticks)
plt.plot(range(10),train_accuracy_rate,label='Train Accuracy Rate')
plt.plot(range(10),validation_accuracy_rate,label='Validation Accuracy Rate')
plt.title('Loss of MNIST Dataset Different Iteration Numbers on Relu Model')
plt.xlabel('Number of Iterations')
plt.ylabel('Accuracy Rate')
plt.legend(loc='upper right')
plt.show()

train_accuracy_rate = np.empty(0)
validation_accuracy_rate = np.empty(0)
xticks = np.empty(0)

reg = 1e-0
for j in xrange(10):
    np.random.seed(0)
    W = 0.01 * np.random.randn(D,h)
    b = np.zeros((1,h))
    np.random.seed(0)
    W2 = 0.01 * np.random.randn(h,K)
    b2 = np.zeros((1,K))
    for i in xrange(100):
        hidden_layer = np.maximum(0, np.dot(train_set_x, W) + b)
        scores = np.dot(hidden_layer, W2) + b2
        exp_scores = np.exp(scores)
        probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
  
        corect_logprobs = -np.log(probs[range(num_examples),train_set_y])
        data_loss = np.sum(corect_logprobs)/num_examples
        reg_loss = 0.5*reg*np.sum(W*W) + 0.5*reg*np.sum(W2*W2)
        loss = data_loss + reg_loss
        if i % 50 == 0:
            print "iteration %d: loss %f" % (i, loss)
  
        dscores = probs
        dscores[range(num_examples),train_set_y] -= 1
        dscores /= num_examples
  
        dW2 = np.dot(hidden_layer.T, dscores)
        db2 = np.sum(dscores, axis=0, keepdims=True)
        dhidden = np.dot(dscores, W2.T)
        dhidden[hidden_layer <= 0] = 0
        dW = np.dot(train_set_x.T, dhidden)
        db = np.sum(dhidden, axis=0, keepdims=True)
  
        dW2 += reg * W2
        dW += reg * W
  
        W += -step_size * dW
        b += -step_size * db
        W2 += -step_size * dW2
        b2 += -step_size * db2

    hidden_layer = np.maximum(0, np.dot(train_set_x, W) + b)
    scores = np.dot(hidden_layer, W2) + b2
    predicted_class = np.argmax(scores, axis=1)
    train_accuracy_rate = np.append(train_accuracy_rate,np.mean(predicted_class == train_set_y))
    
    hidden_layer_test = np.maximum(0, np.dot(valid_set_x, W) + b)
    scores_test = np.dot(hidden_layer_test, W2) + b2
    predicted_class_test = np.argmax(scores_test, axis=1)
    validation_accuracy_rate = np.append(validation_accuracy_rate,np.mean(predicted_class_test == valid_set_y))

    xticks = np.append(xticks,reg)

    reg = reg/10.0

print 'training accuracy rate: %.2f' % (np.mean(predicted_class == train_set_y))
print 'validation accuracy rate: %.2f' % (np.mean(predicted_class_test == valid_set_y))
plt.xticks(range(10),xticks)
plt.plot(range(10),train_accuracy_rate,label='Train Accuracy Rate')
plt.plot(range(10),validation_accuracy_rate,label='Validation Accuracy Rate')
plt.title('Loss of MNIST Dataset Different Regularization Values on Relu Model')
plt.xlabel('Regularization Values')
plt.ylabel('Accuracy Rate')
plt.legend(loc='upper right')
plt.show()

train_accuracy_rate = np.empty(0)
validation_accuracy_rate = np.empty(0)
xticks = np.empty(0)

reg = 0
for j in xrange(10):
    np.random.seed(0)
    W = 0.01 * np.random.randn(D,h)
    b = np.zeros((1,h))
    np.random.seed(0)
    W2 = 0.01 * np.random.randn(h,K)
    b2 = np.zeros((1,K))
    for i in xrange(100):
        hidden_layer = np.maximum(0, np.dot(train_set_x, W) + b)
        scores = np.dot(hidden_layer, W2) + b2
        exp_scores = np.exp(scores)
        probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
  
        corect_logprobs = -np.log(probs[range(num_examples),train_set_y])
        data_loss = np.sum(corect_logprobs)/num_examples
        reg_loss = 0.5*reg*np.sum(W*W) + 0.5*reg*np.sum(W2*W2)
        loss = data_loss + reg_loss
        if i % 50 == 0:
            print "iteration %d: loss %f" % (i, loss)
  
        dscores = probs
        dscores[range(num_examples),train_set_y] -= 1
        dscores /= num_examples
  
        dW2 = np.dot(hidden_layer.T, dscores)
        db2 = np.sum(dscores, axis=0, keepdims=True)
        dhidden = np.dot(dscores, W2.T)
        dhidden[hidden_layer <= 0] = 0
        dW = np.dot(train_set_x.T, dhidden)
        db = np.sum(dhidden, axis=0, keepdims=True)
  
        dW2 += reg * W2
        dW += reg * W
  
        W += -step_size * dW
        b += -step_size * db
        W2 += -step_size * dW2
        b2 += -step_size * db2

    hidden_layer = np.maximum(0, np.dot(train_set_x, W) + b)
    scores = np.dot(hidden_layer, W2) + b2
    predicted_class = np.argmax(scores, axis=1)
    train_accuracy_rate = np.append(train_accuracy_rate,np.mean(predicted_class == train_set_y))
    
    hidden_layer_test = np.maximum(0, np.dot(valid_set_x, W) + b)
    scores_test = np.dot(hidden_layer_test, W2) + b2
    predicted_class_test = np.argmax(scores_test, axis=1)
    validation_accuracy_rate = np.append(validation_accuracy_rate,np.mean(predicted_class_test == valid_set_y))

    xticks = np.append(xticks,reg)

    reg = reg/10.0

print 'training accuracy rate: %.2f' % (np.mean(predicted_class == train_set_y))
print 'validation accuracy rate: %.2f' % (np.mean(predicted_class_test == valid_set_y))
plt.xticks(range(10),xticks)
plt.plot(range(10),train_accuracy_rate,label='Train Accuracy Rate')
plt.plot(range(10),validation_accuracy_rate,label='Validation Accuracy Rate')
plt.title('Loss of MNIST Dataset Regularization Values as Zero on Relu Model')
plt.xlabel('Regularization Values')
plt.ylabel('Accuracy Rate')
plt.legend(loc='upper right')
plt.show()

reg = 1e-3
train_accuracy_rate = np.empty(0)
validation_accuracy_rate = np.empty(0)
xticks = np.empty(0)

percentage = 0.1
for j in xrange(8):
    np.random.seed(0)
    W = 0.01 * np.random.randn(D,h)
    b = np.zeros((1,h))
    np.random.seed(0)
    W2 = 0.01 * np.random.randn(h,K)
    b2 = np.zeros((1,K))
    train_set_x1, train_set_x2, train_set_y1, train_set_y2 = train_test_split(train_set_x, train_set_y, test_size=percentage, random_state=1)
    num_examples = train_set_x1.shape[0]
    for i in xrange(100):
        hidden_layer = np.maximum(0, np.dot(train_set_x1, W) + b)
        scores = np.dot(hidden_layer, W2) + b2
        exp_scores = np.exp(scores)
        probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
  
        corect_logprobs = -np.log(probs[range(num_examples),train_set_y1])
        data_loss = np.sum(corect_logprobs)/num_examples
        reg_loss = 0.5*reg*np.sum(W*W) + 0.5*reg*np.sum(W2*W2)
        loss = data_loss + reg_loss
        if i % 50 == 0:
            print "iteration %d: loss %f" % (i, loss)
  
        dscores = probs
        dscores[range(num_examples),train_set_y1] -= 1
        dscores /= num_examples
  
        dW2 = np.dot(hidden_layer.T, dscores)
        db2 = np.sum(dscores, axis=0, keepdims=True)
        dhidden = np.dot(dscores, W2.T)
        dhidden[hidden_layer <= 0] = 0
        dW = np.dot(train_set_x1.T, dhidden)
        db = np.sum(dhidden, axis=0, keepdims=True)
  
        dW2 += reg * W2
        dW += reg * W
  
        W += -step_size * dW
        b += -step_size * db
        W2 += -step_size * dW2
        b2 += -step_size * db2

    hidden_layer = np.maximum(0, np.dot(train_set_x1, W) + b)
    scores = np.dot(hidden_layer, W2) + b2
    predicted_class = np.argmax(scores, axis=1)
    train_accuracy_rate = np.append(train_accuracy_rate,np.mean(predicted_class == train_set_y1))
    
    hidden_layer_test = np.maximum(0, np.dot(train_set_x2, W) + b)
    scores_test = np.dot(hidden_layer_test, W2) + b2
    predicted_class_test = np.argmax(scores_test, axis=1)
    validation_accuracy_rate = np.append(validation_accuracy_rate,np.mean(predicted_class_test == train_set_y2))

    xticks = np.append(xticks,percentage)

    percentage = percentage + 0.1

print 'training accuracy rate: %.2f' % (np.mean(predicted_class == train_set_y1))
print 'validation accuracy rate: %.2f' % (np.mean(predicted_class_test == train_set_y2))
plt.xticks(range(8),xticks)
plt.plot(range(8),train_accuracy_rate,label='Train Accuracy Rate')
plt.plot(range(8),validation_accuracy_rate,label='Validation Accuracy Rate')
plt.title('Loss of MNIST Dataset Different Data Splits on Relu Model')
plt.xlabel('Test Data Percentage')
plt.ylabel('Accuracy Rate')
plt.legend(loc='upper right')
plt.show()

# %%
#question 6.2
import random
import numpy as np
import matplotlib.pyplot as plt

import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop
from keras.optimizers import SGD

batch_size = 32
num_classes = 10
epochs = 200
data_augmentation = True

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

batch_size = 32
num_classes = 10
epochs = 10

x_train = x_train.reshape(50000,3072)
x_test = x_test.reshape(10000,3072)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %%
#question 6.3
import random
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

N = 100 # number of points per class
D = 2 # dimensionality
K = 3 # number of classes
X = np.zeros((N*K,D))
y = np.zeros(N*K, dtype='uint8')
for j in range(K):
    ix = range(N*j,N*(j+1))
    r = np.linspace(0.0,1,N) # radius
    t = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.2 # theta
    X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
    y[ix] = j

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop
from keras.optimizers import SGD

batch_size = 240
num_classes = 3
epochs = 200

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Dense(512, activation='linear', input_shape=(2,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(2,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

model = Sequential()
model.add(Dense(512, activation='linear', input_shape=(2,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=SGD(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(2,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=SGD(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %%
#IDS 576 Assignment 1 Question 7
#Question 7.1
import os
os.chdir('C:/Users/gupta/Downloads/Adv. Predictive/Assignment 1')
os.getcwd()

#Modified from https://gist.github.com/baraldilorenzo/07d7802847aaad0a35d3
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import SGD
import numpy as np
import json
# %matplotlib inline
import matplotlib.pyplot as plt

from keras import backend as a
a.set_image_dim_ordering('th')


fname = 'imagenet_class_index.json'
with open(fname) as f:
    class_dict = json.load(f)
classes = [class_dict[str(i)][1] for i in range(len(class_dict))]

def VGG_16(weights_path=None):
    model = Sequential()
    model.add(ZeroPadding2D((1,1),input_shape=(3,224,224)))
    model.add(Convolution2D(64, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(64, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(Flatten())
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1000, activation='softmax'))

    if weights_path:
        model.load_weights(weights_path)

    return model

# Test pretrained model
model = VGG_16('C:/Users/gupta/Downloads/Adv. Predictive/Assignment 1/cat1.jpeg')
sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer=sgd, loss='categorical_crossentropy')

from scipy.misc import imread, imresize
# %matplotlib inline
import matplotlib.pyplot as plt

img = imresize(imread('C:/Users/gupta/Downloads/Adv. Predictive/Assignment 1/cat.195.jpg'), (224, 224)).astype(np.float32)
img[:,:,0] -= 103.939
img[:,:,1] -= 116.779
img[:,:,2] -= 123.68
img = img.transpose((2,0,1))
img = np.expand_dims(img, axis=0)
img = img.astype(int)

output = model.predict(img)

#top 5 predictions
for i in range(5):
    print(classes[np.argsort(-output)[0][i]])

# Show the original image
plt.subplot(1, 2, 1)
plt.imshow(np.uint8(imread('C:/Users/gupta/Downloads/Adv. Predictive/Assignment 1/cat.195.jpg')))
plt.show()

from scipy.misc import imread, imresize
# %matplotlib inline
import matplotlib.pyplot as plt

img = imresize(imread('C:/Users/gupta/Downloads/Adv. Predictive/Assignment 1/cat.5206.jpg'), (224, 224)).astype(np.float32)
img[:,:,0] -= 103.939
img[:,:,1] -= 116.779
img[:,:,2] -= 123.68
img = img.transpose((2,0,1))
img = np.expand_dims(img, axis=0)
img = img.astype(int)

output = model.predict(img)

#top 5 predictions
for i in range(5):
    print(classes[np.argsort(-output)[0][i]])

# Show the original image
plt.subplot(1, 2, 1)
plt.imshow(np.uint8(imread('C:/Users/gupta/Downloads/Adv. Predictive/Assignment 1/cat.5206.jpg')))
plt.show()

from scipy.misc import imread, imresize
# %matplotlib inline
import matplotlib.pyplot as plt

img = imresize(imread('C:/Users/gupta/Downloads/Adv. Predictive/Assignment 1/cat.7552.jpg'), (224, 224)).astype(np.float32)
img[:,:,0] -= 103.939
img[:,:,1] -= 116.779
img[:,:,2] -= 123.68
img = img.transpose((2,0,1))
img = np.expand_dims(img, axis=0)
img = img.astype(int)

output = model.predict(img)

#top 5 predictions
for i in range(5):
    print(classes[np.argsort(-output)[0][i]])

# Show the original image
plt.subplot(1, 2, 1)
plt.imshow(np.uint8(imread('C:/Users/gupta/Downloads/Adv. Predictive/Assignment 1/cat.7552.jpg')))
plt.show()


from scipy.misc import imread, imresize
# %matplotlib inline
import matplotlib.pyplot as plt

img = imresize(imread('C:/Users/gupta/Downloads/Adv. Predictive/Assignment 1/cat.8949.jpg'), (224, 224)).astype(np.float32)
img[:,:,0] -= 103.939
img[:,:,1] -= 116.779
img[:,:,2] -= 123.68
img = img.transpose((2,0,1))
img = np.expand_dims(img, axis=0)
img = img.astype(int)

output = model.predict(img)

#top 5 predictions
for i in range(5):
    print(classes[np.argsort(-output)[0][i]])

# Show the original image
plt.subplot(1, 2, 1)
plt.imshow(np.uint8(imread('C:/Users/gupta/Downloads/Adv. Predictive/Assignment 1/cat.8949.jpg')))
plt.show()

# %%
#Question 7.2
import os
def load_img(path):
    images = []
    for file in os.listdir(path):
        image = imread(os.path.join(path,file))
        if image is not None:
            images.append(image)
    return images 
import scipy
from scipy import misc
from scipy.misc.pilutil import imread
#Loading the images from cats folder
abc=load_img('C:/Users/gupta/Downloads/Adv. Predictive/Assignment 1/')
#Loading the images from dogs folder
abc1=load_img('C:/Users/gupta/Downloads/Adv. Predictive/Assignment 1/')

import numpy as np
#cats
X_trn = []
Y_trn = []
for i in range(79):
    img=imresize(abc[i], (224, 224)).astype(np.float32)
    img[:,:,0] -= 103.939
    img[:,:,1] -= 116.779
    img[:,:,2] -= 123.68
    img = img.transpose((2,0,1))
    img = np.expand_dims(img, axis=0)
    output = model.predict(img)
    output=np.reshape(output,1000)
    X_trn.append((output))
    Y_trn.append((0))
#dogs
X_trn1 = []
Y_trn1 = []

for i in range(79):
    img=imresize(abc1[i], (224, 224)).astype(np.float32)
    img[:,:,0] -= 103.939
    img[:,:,1] -= 116.779
    img[:,:,2] -= 123.68
    img = img.transpose((2,0,1))
    img = np.expand_dims(img, axis=0)
    output1 = model.predict(img)
    output1=np.reshape(output1,1000)
    X_trn1.append((output1))
    Y_trn1.append((1))
	
	X_train_complete = X_trn+X_trn1
Y_train_complete = Y_trn+Y_trn1

import numpy as np
X_trn_array = np.asarray(X_train_complete)
Y_trn_array = np.asarray(Y_train_complete) 

#Partitionng the complete data into test and train 80:20 split
import random as random
random.seed(1234)
m = np.random.rand(len(X_trn_array)) < 0.8

X_trn = X_trn_array[m]
Y_trn = Y_trn_array[m]
X_tst = X_trn_array[~m]
Y_tst = Y_trn_array[~m] 

#Linear Classifier
def classifier(X_trn,y_trn, step_size,reg, no_iter ):
    
#Initial value for the Gradient Descent Parameter
    #step_size = 1e-0 #Also called learning rate
    features = X_trn.shape[1] #Number of features 
    noofclass = max(y_trn)+1 #Number of classes assuming class index starts from 0 
    
    np.random.seed(1234)
    W = 0.01 * np.random.randn(features,noofclass)
    b = np.zeros((1,noofclass))
    num_examples = X_trn.shape[0]
#For simplicity, we will not hand tune this algorithm parameter as well.

# gradient descent loop
    for i in range(no_iter):
        #print(no_iter)
    # evaluate class scores, [N x K]
        scores = np.dot(X_trn, W) + b 

        # compute the class probabilities
        exp_scores = np.exp(scores)
        probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True) # [N x K]

        # compute the loss: average cross-entropy loss and regularization
        corect_logprobs = -np.log(probs[range(num_examples),y_trn])
        data_loss = np.sum(corect_logprobs)/num_examples
        reg_loss = 0.5*reg*np.sum(W*W)
        loss = data_loss + reg_loss
        # if i % 10 == 0:
           #print "iteration %d: loss %f" % (i, loss)

        # compute the gradient on scores
        dscores = probs
        dscores[range(num_examples),y_trn] -= 1
        dscores /= num_examples

        # backpropate the gradient to the parameters (W,b)
        dW = np.dot(X_trn.T, dscores)
        db = np.sum(dscores, axis=0, keepdims=True)

        dW += reg*W # regularization gradient

        # perform a parameter update
        W += -step_size * dW
        b += -step_size * db
    
    return(W,b) 
# Post-training: evaluate train set accuracy

W,b = classifier(X_trn, Y_trn, 0.6, 0.001, 10000)
scores = np.dot(X_trn, W) + b
predicted_class = np.argmax(scores, axis=1)
print ('Train accuracy: %.2f' % (np.mean(predicted_class == Y_trn)))

# Post-training: evaluate test set accuracy

scores = np.dot(X_tst, W) + b
predicted_class = np.argmax(scores, axis=1)
print ('Test accuracy: %.2f' % (np.mean(predicted_class == Y_tst)))
